# %%
#DEVELOPER_KEY = "AIzaSyCjk_ldE7BQRys1syakNXnIfhWG_cGf15E"
DEVELOPER_KEY = "AIzaSyBI8uXHhA4j_DZAKm_uCgsbTPHYMBSXWaw"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# %%
from apiclient.discovery import build
from apiclient.errors import HttpError
#from oauth2client.tools import argparser

# %%
def youtube_search(q, max_results=50,order="relevance", token=None, location=None, location_radius=None):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
    developerKey=DEVELOPER_KEY)

    search_response = youtube.search().list(
    q=q,
    type="video",
    pageToken=token,
    order = order,
    part="id,snippet",
    maxResults=max_results,
    location=location,
    locationRadius=location_radius

  ).execute()
    
    videos = []

    for search_result in search_response.get("items", []):
        if search_result["id"]["kind"] == "youtube#video":
            videos.append(search_result)
    try:
        nexttok = search_response["nextPageToken"]
        return(nexttok, videos)
    except Exception as e:
        nexttok = "last_page"
        return(nexttok, videos)

# %%
def geo_query(video_id):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)

    video_response = youtube.videos().list(
        id=video_id,
        part='snippet, recordingDetails, statistics'

    ).execute()

    return video_response

# %%
test = youtube_search("spinners")

# %%
test
# Out:
# ('CDIQAA',
#  [{'kind': 'youtube#searchResult',
#    'etag': 'rHl3GKG3Tpe3qtXvJs_Djy2p7LI',
#    'id': {'kind': 'youtube#video', 'videoId': 'ojCikI9npJQ'},
#    'snippet': {'publishedAt': '2011-10-25T10:25:18Z',
#     'channelId': 'UCyAaxR2630hLkvAWd-9uzgA',
#     'title': 'The Spinners - I&#39;ll Be Around',
#     'description': 'Spinners ©1973 Atlantic.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ojCikI9npJQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ojCikI9npJQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ojCikI9npJQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BakNDaDay',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2011-10-25T10:25:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RqI91K8wCUqhG1u-Lpt2aRtbMXk',
# ...

# %%
video_dict = {'youID':[], 'title':[], 'pub_date':[]}

# test[0] is a six-character string, test[1] is a bunch of JSON
just_json = test[1]
len(just_json)
# Out:
# 50

# %%
# Get the title of a viedo, loop through and pase it with the JSON library

for video in just_json:
    print(video['snippet']['title'])
# Out:
# The Spinners - I&#39;ll Be Around
# The Spinners - Working My Way Back To You (1979)
# The Spinners - Love Don&#39;t Love Nobody (It Takes A Fool)
# Games People Play (LP Version) - Spinners
# The Rubberband Man
# Spinners - a short film starring Timothee Chalamet
# The Spinners ~ I&#39;ll Be Around 1972 Disco Purrfection Version
# The Spinners - Mighty Love
# The Spinners - Sadie
# Spinners - Could It Be I&#39;m Falling In Love
# Spinners  - I&#39;ll Be Around (1973)
# The Spinners - It&#39;s A Shame
# The Spinners - Love Don&#39;t Love Nobody
# The Spinners - Rubberband Man, on Midnight Special in 1976
# The Spinners - Could It Be I&#39;m Falling In Love (Official Vinyl Video)
# The Spinners - Could It Be I&#39;m Falling In Love (1973) (HDTV)
# GAMES PEOPLE PLAY-THE SPINNERS-SOUL TRAIN
# Fidget Spinner Trick Shots | Dude Perfect
# LA TIENDA CON LOS FIDGET SPINNERS MAS IMPRESIONANTES !! - ElChurches VLOG
# Dionne Warwick and The Spinners - Then Came You
# ...

# %%
token = test[0]
youtube_search("spinners", token=token)
# Out:
# ('CGQQAA',
#  [{'kind': 'youtube#searchResult',
#    'etag': '_ldvdPhAJ--QeYfSaZ_5dTW60Tc',
#    'id': {'kind': 'youtube#video', 'videoId': 'y838TzKGrRA'},
#    'snippet': {'publishedAt': '2017-06-26T10:00:30Z',
#     'channelId': 'UC99gvHiLEF9rqkkQi6A6D5A',
#     'title': '5 Awesome Fidget Spinner Tricks',
#     'description': "Hi! Today I'm gonna show you 5 awesome Fidget Spinner Tricks! SUBSCRIBE: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/y838TzKGrRA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/y838TzKGrRA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/y838TzKGrRA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'LHack TV',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-06-26T10:00:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wKK6di5Hl-7rqhFcqM7o47O0YKg',
# ...

# %%
# instantiate a dictionary 
video_dict = {'youID':[], 'title':[], 'pub_date':[]}

# define function
def grab_videos(keyword, token=None):
    res = youtube_search(keyword, token=token)
    token = res[0]
    videos = res[1]
    for vid in videos:
        video_dict['youID'].append(vid['id']['videoId'])
        video_dict['title'].append(vid['snippet']['title'])
        video_dict['pub_date'].append(vid['snippet']['publishedAt'])
    print("added " + str(len(videos)) + " videos to a total of " + str(len(video_dict['youID'])))
    return token   # return the token to be used in the next time we call the function

# %%
token = grab_videos("spinners")
while token != "last_page":
    token = grab_videos("spinners", token=token)
# Out:
# added 50 videos to a total of 50
# added 50 videos to a total of 100
# added 50 videos to a total of 150
# added 50 videos to a total of 200
# added 50 videos to a total of 250
# added 50 videos to a total of 300
# added 50 videos to a total of 350
# added 50 videos to a total of 400
# added 50 videos to a total of 450
# added 50 videos to a total of 500
# added 50 videos to a total of 550
# added 32 videos to a total of 582
# added 0 videos to a total of 582
# added 0 videos to a total of 582
# added 0 videos to a total of 582
# added 0 videos to a total of 582
# added 0 videos to a total of 582
# added 0 videos to a total of 582
# added 0 videos to a total of 582
# added 0 videos to a total of 582

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %%
start_time = datetime(year=2005, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
end_time = datetime(year=2006, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
res = youtube.search().list(q='python', 
                            part='snippet', 
                            type='video', 
                            publishedAfter=start_time,
                            publishedBefore=end_time,
                            maxResults=500).execute()
#req = youtube.search().list(q='Zachary Qin', part='snippet', type='channel', maxResults=50)

# %%
type(req)
# Out:
# dict

# %%
len(res['items'])
# Out:
# 50

# %%
res['items'][1]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'FoU7ahfhb4C1mOtCyzgFkAANUIo',
#  'id': {'kind': 'youtube#video', 'videoId': 'kICWQYWoBAU'},
#  'snippet': {'publishedAt': '2005-10-22T17:39:21Z',
#   'channelId': 'UCsJH3_5q8mWQ4YNdOiU2XVg',
#   'title': 'python feeds',
#   'description': 'rat for dinner.',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kICWQYWoBAU/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/kICWQYWoBAU/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/kICWQYWoBAU/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'vinnyc',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2005-10-22T17:39:21Z'}}

# %%
for item in res['items']:
    print(item['snippet'])
# Out:
# {'publishedAt': '2005-12-12T21:00:36Z', 'channelId': 'UC358-3iPppyKaT4kMPbkS8w', 'title': 'monty python -dirty Hungarian handbook', 'description': 'dirty hungarian handbook.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/k_Gn6a3WbYw/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/k_Gn6a3WbYw/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/k_Gn6a3WbYw/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Bosha Josh', 'liveBroadcastContent': 'none', 'publishTime': '2005-12-12T21:00:36Z'}
# ...

# %%
from datetime import datetime

# %%
start_time = datetime(year=2005, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
end_time = datetimeyear=2006, month=1, day=1).strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
start_time
# Out:
# '2005-01-01T00:00:00Z'
